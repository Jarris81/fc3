# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("z.costReport")
#df.index = (np.arange(len(df)))

df.plot(figsize=(20, 20))
plt.show()

# %%
values = df.to_numpy()
features = df.columns
for icol, irow in np.nonzero(values > 0.1):
    print(f'Feature {features[icol]} at switch #{irow} is not feasible!')
# Out:
# Feature F_qItself/1-#32 at switch #0 is not feasible!
# Feature  F_PositionRel/0-R_gripperCenter-b2 at switch #4 is not feasible!

# %%
df.name = "transient"
df
# Out:
#    F_qItself/1-#32   F_qQuaternionNorms/0-#90   F_AccumulatedCollisions/0-#90  \
# 0         0.011152               8.411570e-07                    9.280770e-16
# 1         0.009158               1.380530e-06                    9.280770e-16
# 2         0.009092               8.141930e-07                    9.280770e-16
# 3         0.007201               1.152730e-06                    9.280770e-16
# 4         0.002903               1.314580e-06                    0.000000e+00
# 5         0.002052               1.329610e-06                    0.000000e+00
# 6         0.001781               1.603350e-06                    0.000000e+00
# 7         0.002318               1.451080e-06                    0.000000e+00
#
#     F_PositionRel/0-R_gripperCenter-b2   F_VectorDiff/0-R_gripper-b2  \
# 0                              14.8446                      0.533876
# 1                               0.0000                      0.000000
# ...

# %%
np.nonzero(values > 0.1)
# Out:
# (array([0, 0]), array([3, 4]))
